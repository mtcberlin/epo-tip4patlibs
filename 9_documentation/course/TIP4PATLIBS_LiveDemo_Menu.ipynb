# %% [markdown]
# <div style="font-family: system-ui, -apple-system, sans-serif; text-align: center; padding: 48px 24px 24px;">
#     <div style="display: inline-block; background: #be0f05; color: white;
#                 padding: 12px 20px; border-radius: 12px; margin-bottom: 20px;">
#         <span style="font-size: 36px; font-weight: 800; letter-spacing: -0.5px;">TIP4PATLIBS &ndash; Live Demo Main Menu</span>
#     </div>
#     <div style="font-size: 16px; color: #475569; margin-bottom: 8px; line-height: 1.6;">
#         One place to open every notebook, finished result and slide deck used on stage &mdash; <strong>PATLIB Conference, Warsaw, 16&ndash;17 September 2026</strong> (same presentation, both sessions).
#     </div>
#     <div style="font-size: 13px; color: #94a3b8; margin-bottom: 32px;">
#         EPO Academy Training Material &nbsp;&middot;&nbsp; <a href="https://patentreports.depa.tech" target="_blank"
#            style="color: #be0f05; text-decoration: none; font-weight: 600;">created by Arne Kr&uuml;ger</a>
#     </div>
#     <div style="background: #f8fafc; border-radius: 12px; padding: 24px 28px; max-width: 680px;
#                 margin: 0 auto; border: 1px solid #e2e8f0; text-align: left;">
#         <div style="font-size: 14px; color: #334155; line-height: 1.9;">
#             <strong>Two topics on stage, each a full chain from search strategy to finished result</strong>
#             <br/>Topic&nbsp;A &nbsp;&middot;&nbsp; <strong>Patent Valuation</strong> &mdash; the IPScore rebuild (module 8)
#             <br/>Topic&nbsp;B &nbsp;&middot;&nbsp; <strong>Patent Landscape</strong> &mdash; the Antibiotic Resistance rebuild (module 6)
#         </div>
#     </div>
#     <div style="background: #fdf2f2; border-radius: 10px; padding: 16px 24px; max-width: 680px;
#                 margin: 28px auto 0; border: 1px solid #fecaca;">
#         <div style="font-size: 14px; color: #404955; font-weight: 600;">&#9654; &nbsp;How this menu works.</div>
#         <div style="font-size: 12px; color: #64748b; margin-top: 6px; line-height: 1.6;">
#             <strong>Notebook links</strong> (blue, in the lists below) open that notebook in a new JupyterLab tab &mdash;
#             click and it loads top to bottom as usual. <strong>Slide &amp; outcome buttons</strong> (red, from a code
#             cell) open the deck or the finished result live inside TIP through the course's <code>open_html()</code>
#             proxy helper &mdash; the slide decks live right here in <code>0_live_demo/</code>, the outcomes in each
#             module's own folder. An <code>IFrame</code> cannot show these artifacts here &mdash; JupyterLab's CSP
#             sandbox blocks their JavaScript &mdash; so run the setup cell once, then use the buttons.
#         </div>
#     </div>
#     <div style="margin-top: 20px; font-size: 12px; color: #cbd5e1;">
#         Part of EPO TIP Working Group Sessions, 2026. &nbsp;This menu links to material only; it changes nothing in either module.
#     </div>
# </div>

# %% [markdown]
# ## Setup &mdash; run once
#
# Connects this notebook to the shared `open_html()` helper (`1_startwithtip/tip_tools.py`), the same one
# modules 6, 7 and 8 already use to show their finished HTML results inside TIP.

# %%
import sys
from pathlib import Path

root = next((p for p in [Path.cwd(), *Path.cwd().parents]
             if (p / "CLAUDE.md").exists()), Path.cwd())
sys.path.insert(0, str(root / "1_startwithtip"))

from tip_tools import open_html

print("Ready. Use the notebook links below to open a step, or run an 'Open outcome' cell to show a finished result.")

# %% [markdown]
# ---
#
# ## Topic A &middot; Patent Valuation &mdash; IPScore rebuild
#
# *What is this patent worth, and how much of that number is evidence rather than judgement?*
# Source folder: [`6_ipscore_rebuild/`](../../6_ipscore_rebuild/)
#
# | # | Notebook | Answers |
# |---|----------|---------|
# | 0 | [`0_questionnaire.ipynb`](../../6_ipscore_rebuild/0_questionnaire.ipynb) &nbsp;&mdash;&nbsp; **start here** | Enter a patent, company figures and the 40 IPScore answers (optional &mdash; ships with a worked example) |
# | 1 | [`1_the_model.ipynb`](../../6_ipscore_rebuild/1_the_model.ipynb) | What the model is, and does our engine reproduce the EPO Excel exactly? |
# | 2 | [`2_evidence_from_patstat.ipynb`](../../6_ipscore_rebuild/2_evidence_from_patstat.ipynb) | For the worked patent: what can PATSTAT actually answer? |
# | 3 | [`3_valuation_and_scenarios.ipynb`](../../6_ipscore_rebuild/3_valuation_and_scenarios.ipynb) | What is it worth, and which lever moves that number most? |
# | 4 | [`4_assemble_tool.ipynb`](../../6_ipscore_rebuild/4_assemble_tool.ipynb) | Assembles the outcome below: one self-contained HTML valuation + one data workbook |

# %%
open_html("TIP4PATLIBS_IPScore_NotebookLogic_Explained_con_note.pptx",
          "Slides \u2014 IPScore, notebook logic explained (with speaker notes)")

# %%
open_html("../../6_ipscore_rebuild/4_tool/ipscore_valuation.html",
          "Outcome \u2014 IPScore valuation (ipscore_valuation.html)")

# %% [markdown]
# ---
#
# ## Topic B &middot; Patent Landscape &mdash; Antibiotic Resistance rebuild
#
# *Turning a patent dataset into a publishable landscape report &mdash; the search strategy is the actual
# professional skill.* Source folder: [`5_patentreports/antibiotic_resistance/`](../../5_patentreports/antibiotic_resistance/)
#
# | # | Notebook | Answers |
# |---|----------|---------|
# | 1 | [`1_dataset_and_search_strategy.ipynb`](../../5_patentreports/antibiotic_resistance/1_dataset_and_search_strategy.ipynb) &nbsp;&mdash;&nbsp; **start here** | How is the corpus defined? Keywords **and** classifications, deliberate exclusions |
# | 2 | [`2_core_landscape_analyses.ipynb`](../../5_patentreports/antibiotic_resistance/2_core_landscape_analyses.ipynb) | Who / where / when &mdash; authorities, national trends, filing strategy, top applicants, sectors, grant rate |
# | 3 | [`3_advanced_analyses.ipynb`](../../5_patentreports/antibiotic_resistance/3_advanced_analyses.ipynb) | The IPC technology co-occurrence network |
# | 4 | [`4_assemble_report.ipynb`](../../5_patentreports/antibiotic_resistance/4_assemble_report.ipynb) | Assembles the outcome below: one self-contained HTML report + one data workbook |

# %%
open_html("TIP4PATLIBS_AntibioticResistance_LiveDemo_Warsaw2026.pptx",
          "Slides \u2014 Antibiotic Resistance, live demo deck")

# %%
open_html("../../5_patentreports/antibiotic_resistance/4_report/antibiotic_resistance_report.html",
          "Outcome \u2014 Antibiotic Resistance landscape report (antibiotic_resistance_report.html)")
