# %% [markdown]
# <div style="font-family: system-ui, -apple-system, sans-serif; text-align: center; padding: 48px 24px 24px;">
#     <div style="display: inline-block; background: #be0f05; color: white;
#                 padding: 12px 20px; border-radius: 12px; margin-bottom: 20px;">
#         <span style="font-size: 36px; font-weight: 800; letter-spacing: -0.5px;">TIP4PATLIBS - PATSTAT Explorer</span>
#     </div>
#     <div style="font-size: 16px; color: #475569; margin-bottom: 8px; line-height: 1.6;">
#         Patent analysis &amp; visualization on EPO Technology Integlligence Platform
#     </div>
#     <div style="font-size: 13px; color: #94a3b8; margin-bottom: 32px;">
#         <a href="https://depa.tech" target="_blank"
#            style="color: #be0f05; text-decoration: none; font-weight: 600;">depa.tech</a>
#         &nbsp;·&nbsp; EPO Academy Training Material
#     </div>
#     <div style="background: #f8fafc; border-radius: 12px; padding: 24px 28px; max-width: 540px;
#                 margin: 0 auto; border: 1px solid #e2e8f0; text-align: left;">
#         <div style="font-size: 14px; color: #334155; line-height: 1.8;">
#             Search and analyse patent data from the EPO PATSTAT database —
#             applicant names, co-filing networks, citations,
#             technology classifications and more.
#             <br/><br/>
#             Includes an <strong>AI Query Generator</strong> powered by a
#             <a href="https://github.com/mtcberlin/mtc-patstat-mcp-lite" target="_blank"
#                style="color: #be0f05; text-decoration: none; font-weight: 600;">PATSTAT MCP</a>
#             server — ask questions in natural language and let Claude
#             use its schema knowlegde and build the SQL for you.
#         </div>
#     </div>
#     <div style="background: #fdf2f2; border-radius: 10px; padding: 16px 24px; max-width: 540px;
#                 margin: 28px auto 0; border: 1px solid #fecaca;">
#         <div style="font-size: 14px; color: #404955; font-weight: 600;">▶ &nbsp;Run the cell below to start</div>
#         <div style="font-size: 12px; color: #64748b; margin-top: 6px; line-height: 1.6;">
#             First launch downloads &amp; installs everything (~1–2 min).<br/>
#             Subsequent starts are fast (~10 s).
#         </div>
#     </div>
#     <div style="margin-top: 20px; font-size: 12px; color: #cbd5e1;">
#         To stop: restart the server.
#     </div>
# </div>

# %%
import subprocess, os, sys
from pathlib import Path
from IPython.display import display, HTML, clear_output

REPO_URL = "https://github.com/mtcberlin/epo-tip-svelte-patstat-explorer.git"
APP_DIR = Path.home() / "epo-tip-svelte-patstat-explorer"

def _status(msg):
    clear_output(wait=True)
    display(HTML(f"""
    <div style=\"font-family: system-ui, sans-serif; padding: 20px;
                background: #f8fafc; border-left: 4px solid #be0f05;
                border-radius: 8px;\">
        <div style=\"font-size: 15px; color: #334155;\">⏳ {msg}</div>
    </div>"""))

if (APP_DIR / ".git").is_dir():
    _status("Updating TIP4PATLIBs PATSTAT Explorer...")
    subprocess.run(["git", "-C", str(APP_DIR), "pull", "--ff-only"],
                   capture_output=True, text=True)
else:
    _status("Downloading TIP4PATLIBs PATSTAT Explorer (first run)...")
    subprocess.run(["git", "clone", REPO_URL, str(APP_DIR)],
                   capture_output=True, text=True, check=True)

os.chdir(str(APP_DIR))

# launch.py uses __file__ to find PROJECT_DIR — provide it for exec()
launch_path = str(APP_DIR / "launch.py")
exec(compile(open(launch_path).read(), launch_path, "exec"), {**globals(), "__file__": launch_path})
# Out:
#             <div style="font-family: system-ui, sans-serif; text-align: center; padding: 32px;">
#                 <div style="font-size: 15px; color: #059669; font-weight: 600; margin-bottom: 16px;">
#                     ✅ PATSTAT Explorer is running
#                 </div>
#                 <a href="/user/YSEnMLHtRnAwezLvvPk3kt/proxy/52080/" target="_blank"
#                    style="display: inline-block; padding: 14px 32px;
#                           background: #be0f05;
#                           color: white; border-radius: 8px; text-decoration: none;
#                           font-size: 16px; font-weight: 600;
#                           box-shadow: 0 2px 8px rgba(190, 15, 5, 0.3);">
#                     PATSTAT Explorer open &rarr;
#                 </a>
#                 <div style="margin-top: 12px; font-size: 12px; color: #9ca3af;">
#                     Node v24.4.1 &middot; Port 52080
#                 </div>
#             </div>
